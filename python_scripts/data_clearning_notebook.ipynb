# %%
import pandas as pd

# %%
nyc_path = '../datasets/NYC_AIRBNB.csv'
boston_path = '../datasets/BOSTON_LISTING.csv'

# %%
nyc_df = pd.read_csv(nyc_path)
boston_df = pd.read_csv(boston_path)

# %%
nyc_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
nyc_df = nyc_df.drop('name', axis=1)

# %%
nyc_df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
nyc_df = nyc_df.drop(labels=['host_name', 'last_review', 'reviews_per_month'], axis=1)

# %%
nyc_df
# Out:
#              id   host_id neighbourhood_group       neighbourhood  latitude  \
# 0          2539      2787            Brooklyn          Kensington  40.64749
# 1          2595      2845           Manhattan             Midtown  40.75362
# 2          3647      4632           Manhattan              Harlem  40.80902
# 3          3831      4869            Brooklyn        Clinton Hill  40.68514
# 4          5022      7192           Manhattan         East Harlem  40.79851
# ...         ...       ...                 ...                 ...       ...
# 48890  36484665   8232441            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891  36485057   6570630            Brooklyn            Bushwick  40.70184
# 48892  36485431  23492952           Manhattan              Harlem  40.81475
# 48893  36485609  30985759           Manhattan      Hell's Kitchen  40.75751
# 48894  36487245  68119814           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
nyc_df['room_type'] = nyc_df['room_type'].astype('category')
nyc_df['room_type_cat'] = nyc_df['room_type'].cat.codes

# %%
nyc_df['neighbourhood'] = nyc_df['neighbourhood'].astype('category')
nyc_df['neighbourhood_cat'] = nyc_df['neighbourhood'].cat.codes

# %%
nyc_df
# Out:
#              id   host_id neighbourhood_group       neighbourhood  latitude  \
# 0          2539      2787            Brooklyn          Kensington  40.64749
# 1          2595      2845           Manhattan             Midtown  40.75362
# 2          3647      4632           Manhattan              Harlem  40.80902
# 3          3831      4869            Brooklyn        Clinton Hill  40.68514
# 4          5022      7192           Manhattan         East Harlem  40.79851
# ...         ...       ...                 ...                 ...       ...
# 48890  36484665   8232441            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891  36485057   6570630            Brooklyn            Bushwick  40.70184
# 48892  36485431  23492952           Manhattan              Harlem  40.81475
# 48893  36485609  30985759           Manhattan      Hell's Kitchen  40.75751
# 48894  36487245  68119814           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
nyc_df['neighbourhood_group'] = nyc_df['neighbourhood_group'].astype('category')
nyc_df['neighbourhood_group_cat'] = nyc_df['neighbourhood_group'].cat.codes

# %%
nyc_df
# Out:
#              id   host_id neighbourhood_group       neighbourhood  latitude  \
# 0          2539      2787            Brooklyn          Kensington  40.64749
# 1          2595      2845           Manhattan             Midtown  40.75362
# 2          3647      4632           Manhattan              Harlem  40.80902
# 3          3831      4869            Brooklyn        Clinton Hill  40.68514
# 4          5022      7192           Manhattan         East Harlem  40.79851
# ...         ...       ...                 ...                 ...       ...
# 48890  36484665   8232441            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891  36485057   6570630            Brooklyn            Bushwick  40.70184
# 48892  36485431  23492952           Manhattan              Harlem  40.81475
# 48893  36485609  30985759           Manhattan      Hell's Kitchen  40.75751
# 48894  36487245  68119814           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
nyc_df['price']/nyc_df['number_of_reviews']
# Out:
# 0        16.555556
# 1         5.000000
# 2              inf
# 3         0.329630
# 4         8.888889
#            ...
# 48890          inf
# 48891          inf
# 48892          inf
# 48893          inf
# 48894          inf
# Length: 48895, dtype: float64

# %%
boston_df = pd.read_csv(boston_path)

# %%
pd.set_option('display.max_rows', 500)
boston_df.isnull().sum()
# Out:
# id                                     0
# listing_url                            0
# scrape_id                              0
# last_scraped                           0
# name                                   0
# summary                              143
# space                               1057
# description                            0
# experiences_offered                    0
# neighborhood_overview               1415
# notes                               1975
# transit                             1290
# access                              1489
# interaction                         1554
# house_rules                         1192
# thumbnail_url                        599
# medium_url                           599
# picture_url                            0
# xl_picture_url                       599
# host_id                                0
# host_url                               0
# host_name                              0
# host_since                             0
# ...

# %%
boston_df = boston_df.drop(labels=['city', 'host_location', 'neighbourhood', 'space', 'transit', 'access', 'interaction', 'weekly_price', 'monthly_price', 'square_feet', 'neighbourhood_group_cleansed'], axis=1)

# %%
boston_df['property_type'].value_counts()
# Out:
# Apartment          2612
# House               562
# Condominium         231
# Townhouse            54
# Bed & Breakfast      41
# Loft                 39
# Other                17
# Boat                 12
# Villa                 6
# Entire Floor          4
# Dorm                  2
# Camper/RV             1
# Guesthouse            1
# Name: property_type, dtype: int64

# %%
boston_df['property_type'] = boston_df['property_type'].fillna('Aprtament')

# %%
boston_df['beds'].fillna(1.0, inplace=True)

# %%
boston_df['bedrooms'].fillna(1.0, inplace=True)

# %%
boston_df['bathrooms'].fillna(1.0, inplace=True)

# %%
boston_df['neighbourhood'].isnull().sum()
# Out:
# 543

# %%
boston_df['neighbourhood'].value_counts()
# Out:
# Allston-Brighton      364
# Jamaica Plain         314
# South End             298
# Back Bay              291
# Fenway/Kenmore        249
# South Boston          216
# Dorchester            195
# Beacon Hill           174
# North End             125
# East Boston           117
# Roxbury               116
# Mission Hill          103
# Charlestown            79
# Chinatown              78
# West End               68
# Roslindale             50
# West Roxbury           35
# Theater District       33
# Downtown Crossing      26
# Hyde Park              25
# Mattapan               20
# Somerville             13
# Financial District     13
# Leather District        8
# Brookline               8
# Downtown                8
# Cambridge               7
# Chestnut Hill           4
# Government Center       3
# Harvard Square          2
# Name: neighbourhood, dtype: int64

# %%
boston_df['neighbourhood_cleansed'].value_counts()
# Out:
# Jamaica Plain              343
# South End                  326
# Back Bay                   302
# Fenway                     290
# Dorchester                 269
# Allston                    260
# Beacon Hill                194
# Brighton                   185
# South Boston               174
# Downtown                   172
# East Boston                150
# Roxbury                    144
# North End                  143
# Mission Hill               124
# Charlestown                111
# South Boston Waterfront     83
# Chinatown                   71
# Roslindale                  56
# West End                    49
# West Roxbury                46
# Hyde Park                   31
# Bay Village                 24
# Mattapan                    24
# Longwood Medical Area        9
# Leather District             5
# Name: neighbourhood_cleansed, dtype: int64

# %%
boston_df['review_scores_rating'].fillna(0.0)
# Out:
# 0         0.0
# 1        94.0
# 2        98.0
# 3       100.0
# 4        99.0
#         ...
# 3580     90.0
# 3581      0.0
# 3582      0.0
# 3583     90.0
# 3584      0.0
# Name: review_scores_rating, Length: 3585, dtype: float64

# %%
boston_df['cleaning_fee'] = boston_df['cleaning_fee'].apply(lambda x: float(x.replace('$', '')) if isinstance(x, str) else x)

# %%
boston_df['cleaning_fee'].fillna(68)
# Out:
# 0       35.0
# 1       10.0
# 2       68.0
# 3       50.0
# 4       15.0
#         ...
# 3580    68.0
# 3581    15.0
# 3582    68.0
# 3583    68.0
# 3584    25.0
# Name: cleaning_fee, Length: 3585, dtype: float64

# %%
boston_df['weekly_price']
# Out:
# 0           NaN
# 1       $400.00
# 2       $395.00
# 3           NaN
# 4           NaN
#          ...
# 3580        NaN
# 3581        NaN
# 3582        NaN
# 3583        NaN
# 3584        NaN
# Name: weekly_price, Length: 3585, dtype: object
